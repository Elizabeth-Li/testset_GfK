# %% [markdown]
# # Task 2: Text Classification

# %%
# obtain the data
# !pip install -U pandas
# !pip install -U nltk
import pandas as pd
data = pd.read_csv('testset_C.csv', sep=';')
data.head()
# Out:
#          id     productgroup  \
# 0  26229701  WASHINGMACHINES
# 1  16576864       USB MEMORY
# 2  26155618       USB MEMORY
# 3  25646138         BICYCLES
# 4  19764614         BICYCLES
#
#                                            main_text  \
# 0                                          WAQ284E25
# 1  LEEF IBRIDGE MOBILE SPEICHERERWEITERUNG FUER I...
# 2                     SANDISK 32GB ULTRA FIT USB 3.0
# 3  HOLLANDRAD DAMEN 28 ZOLL TUSSAUD 3-GAENGE RH 5...
# 4                   DAHON SPEED D7 SCHWARZ ? FALTRAD
#
#                                    add_text         manufacturer
# 0                            WASCHMASCHINEN                BOSCH
# 1  PC__1100COMPUTINGMEMORY__1110MEMORYCARDS                 LEEF
# 2                                     W1370                  NaN
# 3             FAHRRAEDER // SPORTFAHRRAEDER  SCHALOW & KROH GMBH
# 4          SPORTS__30000WHEELED__30070BIKES                DAHON

# %% [markdown]
# Before developing any classification models, I would first take a look at (i) how many entries the dataset has, and (ii) the distribution of the labels (productgroup).

# %%
from nltk import FreqDist
category_list = data['productgroup'].tolist()
unique_ctg = list(set(category_list))
print('num of product group', len(unique_ctg))

ctg_fd = FreqDist(category_list)
ctg_fd.most_common()
# Out:
# num of product group 4
# [('WASHINGMACHINES', 2000),
#  ('USB MEMORY', 2000),
#  ('BICYCLES', 2000),
#  ('CONTACT LENSES', 2000)]

# %% [markdown]
# Hence the dataset is balanced. There are three columns from which I can make predictions: *main_text*, *add_text* and *manufacturer*. Among them, manufacturer is categorial information, while main_text and add_text are free-text unstructured information. Hence, I would go from easy to hard: first use only manufacturers to make predictions, and then try to use the free-text information.

# %%
# count how many unique manufacturers we have, and the frequency of each manufacturer
from nltk import FreqDist
manufacture_list = data['manufacturer'].tolist()
unique_mnf = list(set(manufacture_list))
print('num of unique manufacturers', len(unique_mnf))

mnf_fd = FreqDist(manufacture_list)
mnf_fd.most_common()
# Out:
# num of unique manufacturers 624
# [(nan, 1344),
#  ('COOPER', 343),
#  ('CIBA', 243),
#  ('SIEMENS', 205),
#  ('MIELE', 197),
#  ('B&L', 181),
#  ('SANDISK', 176),
#  ('J&J', 175),
#  ('BOSCH', 173),
#  ('ALCON', 172),
#  ('TRANSCEND', 161),
#  ('AEG', 149),
#  ('VERBATIM', 140),
#  ('CUBE', 126),
#  ('KINGSTON', 125),
#  ('INTENSO', 103),
#  ('VESTEL GERMANY GMBH', 86),
#  ('BERGAMONT', 80),
#  ('SAMSUNG', 75),
#  ('BAUKNECHT', 74),
#  ('BEKO', 72),
#  ('SERIOUS', 71),
#  ('MPG&E', 68),
#  ('GHOST', 66),
#  ('MERIDA', 63),
#  ('SILICON POWER', 61),
#  ('KS CYCLING', 59),
#  ('HAMA', 54),
#  ('ACUVUE', 52),
#  ('EMTEC', 52),
#  ('TOSHIBA', 52),
#  ('WINORA', 52),
#  ('CORSAIR', 51),
#  ('BICYCLES', 48),
#  ('FUJI', 48),
#  ('BOCAS', 43),
#  ('CONSTRUCTA', 42),
#  ('LEXAR', 42),
#  ('JOHNSON & JOHNSON', 39),
#  ('ORTLER', 38),
#  ('OTTO GMBH & CO. KG', 38),
#  ('GOODRAM', 36),
#  ('SCHALOW & KROH GMBH', 35),
#  ('GORENJE', 35),
#  ('PUKY', 35),
#  ('SONY', 34),
#  ('GAZELLE', 33),
#  ('RALEIGH', 33),
#  ("S'COOL", 33),
#  ('COOPER VISION', 32),
#  ('BEKO DEUTSCHLAND GMBH', 32),
#  ('XLYNE', 32),
#  ('FIXIE INC.', 30),
#  ('WOEHLKZEIS', 29),
#  ('VOTEC', 28),
#  ('ROBERT BOSCH HAUSGERAETE GMBH', 27),
#  ('CREME', 27),
#  ('HAIBIKE', 26),
#  ('TRIBE', 24),
#  ('BACHTENKIRCH', 24),
#  ('CNMEMORY', 24),
#  ('BAUSCH + LOMB', 22),
#  ('HOOVER', 22),
#  ('INTEGRAL', 22),
#  ('LEEF', 21),
#  ('GIANT', 20),
#  ('INDESIT', 20),
#  ('SEG HAUSGERAETE GMBH', 20),
#  ('CANDY', 19),
#  ('KONA', 18),
#  ('MIFA MITTELDEUTSCHE FAHRRADWERKE AG', 18),
#  ('SCOTT', 18),
#  ('SAUFLON', 17),
#  ('SI ZWEIRAD VERTRIEBS GMBH', 17),
#  ('VERMONT', 17),
#  ('ZANKER', 17),
#  ('Bosch Hausgeräte GmbH', 17),
#  ('COOPERVISION', 17),
#  ('KETTLER', 17),
#  ('SPRICK CYCLE GMBH', 17),
#  ('ADATA', 16),
#  ('COMPEL', 16),
#  ('ORBEA', 16),
#  ('PNY ELECTRONICS', 16),
#  ('CORRATEC', 15),
#  ('EXQUISIT', 15),
#  ('HAIER', 15),
#  ('ARICONA', 14),
#  ('PROPHETE', 14),
#  ('ZANUSSI', 14),
#  ('A-DATA', 14),
#  ('UNIVEGA', 14),
#  ('PNY', 13),
#  ('PATRIOT', 13),
#  ('KSCA5|#KS CYCLING', 13),
#  ('PHILIPS', 13),
#  ('TRENDMAXX GMBH', 12),
#  ('Fashion_EAN', 12),
#  ('KINGSTON TECHNOLOGY', 12),
#  ('VIKING', 12),
#  ('BAUSCH & LOMB', 12),
#  ('BOMANN', 12),
#  ('CROSS', 12),
#  ('PLATINUM', 12),
#  ('CENTURION', 12),
#  ('LG', 12),
#  ('V7', 11),
#  ('KINGSTON TECHNOLOGIES', 11),
#  ('ZEG', 11),
#  ('AIR OPTIX', 11),
#  ('HECHT', 11),
#  ('COOPERVISION GMBH', 11),
#  ('MIFA-BIKE GESELLSCHAFT MBH', 10),
#  ('HYDROGEL V', 9),
#  ('ALCON PHARMA GMBH', 9),
#  ('A E G', 9),
#  ('SI-ZWEIRAD-VERTRIEBS-GMBH', 9),
#  ('PEGASUS ZEG', 9),
#  ('SIEMENS-HAUSGERäTE', 9),
#  ('COOPER VISION GMBH', 9),
#  ('BEKO GRUNDIG Deutschland GmbH', 9),
#  ('MIELE & CIE. KG', 9),
#  ('BULLS ZEG', 9),
#  ('ACUVUE KONTAKTLINSEN', 9),
#  ('TAKEMS SONDERPOSTEN', 8),
#  ('UNBRANDED', 8),
#  ('SI-ZWEIRAD-VERTRIEBS GMBH', 8),
#  ('MERALENS', 8),
#  ('PANASONIC', 8),
#  ('TRANSCEND INFORMATION TRADING GMBH', 8),
#  ('PENTAGON SALES GMBH', 8),
#  ('WOEHLK', 8),
#  ('ELECTRA', 8),
#  ('COLOURVUE', 8),
#  ('GRUNDIG', 8),
#  ('BAUSCH&LOMB', 8),
#  ('LACIE', 8),
#  ('BEKO Deutschland GmbH', 8),
#  ('MENICON GMBH', 7),
#  ('SCOTT SPORTS AG', 7),
#  ('GENIE', 7),
#  ('CIBA VISION', 7),
#  ('FELT', 7),
#  ('EVB HANDELSHAUS BOUR GMBH', 7),
#  ('MBM', 7),
#  ('SILVER HT', 7),
#  ('ELECTROLUX', 7),
#  ('BACH', 7),
#  ('AMICA', 7),
#  ('TOSHIBA - MASS STORAGE', 6),
#  ('SONSTIGES', 6),
#  ('NILOX STORAGE', 6),
#  ('TDK', 6),
#  ('MEDIACOM AG', 6),
#  ('SAFILENS', 6),
#  ('RIXE', 6),
#  ('DIVERSE', 6),
#  ('MEDIA MARKT E-COMMERCE', 6),
#  ('MENICON', 6),
#  ('BLOMBERG', 6),
#  ('SIEMENS ELECTROGERAETE GMBH', 6),
#  ('BIKEEUROPE', 6),
#  ('HECHT CONTACTLINSEN GMBH', 6),
#  ('SPECIALIZED', 6),
#  ('CONSUMABILI VERBATIM', 5),
#  ('AEG ELECTROLUX', 5),
#  ('BAUKNECHT HAUSGERAETE GMBH', 5),
#  ('CONTA OPTIC', 5),
#  ('HISENSE', 5),
#  ('VERBATIM CORPORATION', 5),
#  ('NO 7', 5),
#  ('INTENSO GMBH', 5),
#  ('MPG&E-CONTACTLINSEN', 5),
#  ('ISTORAGE', 5),
#  ('LEXAR IMAGING', 5),
#  ('FOCUS BIKES', 5),
#  ('CHIPS AND MORE GMBH', 5),
#  ('CLEARLAB', 5),
#  ("MARK'ENNOVY", 5),
#  ('CONSUM.SONY', 5),
#  ('BOSCH ROB.HAUSGERAETE GMBH', 4),
#  ('KREIDLER', 4),
#  ('LIV', 4),
#  ('WÖHLK', 4),
#  ('BAUSCH & LOMB GMBH', 4),
#  ('IMATION', 4),
#  ('PHOTOFAST', 4),
#  ('PERFORMANCE', 4),
#  ('MIFA', 4),
#  ('LEXAR MEDIA INC', 4),
#  ('4CARE GMBH', 4),
#  ('COOPER-EIGENMARKE', 4),
#  ('BIRIA', 4),
#  ('CONSUMER', 4),
#  ('PENDING SYSTEM GMBH&CO.KG,,956', 4),
#  ('FISCHER', 4),
#  ('FOCUS', 4),
#  ('HECHT CONTACTLINSEN', 4),
#  ('HAM', 4),
#  ('Despec', 4),
#  ('HETYCH KONTAKTLINSEN KG', 4),
#  ('ARP OE PRODUCT', 4),
#  ('DAHON', 3),
#  ('HAMA GMBH & CO.KG', 3),
#  ('JENALENS', 3),
#  ('SIEMENS-ELECTROGER?TE GMBH', 3),
#  ('SIEMENS-HAUSGERAETE', 3),
#  ('SIEMENS ELECTROGERÃ¤TE GMBH', 3),
#  ('MUSHKIN', 3),
#  ('BACH OPTIK', 3),
#  ('BUENTING SYSTEMKUNDEN HANDELS-GMBH', 3),
#  ('UFP DEUTSCHLAND GMBH', 3),
#  ('INNOVA', 3),
#  ('SDI', 3),
#  ('MPG', 3),
#  ('BOMBTRACK', 3),
#  ('SOENNECKEN EG', 3),
#  ('GGV-IMPORT-EXPORT', 3),
#  ('BOSCH HAUSTECHNIK', 3),
#  ('BAUKNECHT HAUSGERATE GMBH', 3),
#  ('SEG HAUSGERAETE GMBH96034', 3),
#  ('MOBILITY LAB', 3),
#  ('SHARKOON', 3),
#  ('BAUKNECHT HAUSGERGMBH', 3),
#  ('KWIKSIBS', 3),
#  ('COOPER VISION  G.M.B.H.', 3),
#  ('PUKY GMBH', 3),
#  ('CYOU', 3),
#  ('Hecht', 3),
#  ('DIAMONDBACK', 3),
#  ('CONSTRUCTA ENERGY', 3),
#  ('PURE FIX CYCLES', 3),
#  ('SOENNECKEN', 3),
#  ('WÖHLK CONTACT-LINSEN', 3),
#  ("SCP8J|#S'COOL", 3),
#  ('BOMANNC.GMBH', 3),
#  ('HAWK GREEN ENERGY', 3),
#  ('BIOFINITY', 3),
#  ('RABENEICK', 3),
#  ('BROMPTON', 3),
#  ('SAUFLON PH', 3),
#  ('ROBERT BOSCH GMBH', 3),
#  ('VCM MORGENTHALER GMBH', 3),
#  ('CONTA OPTIC GMBH', 3),
#  ('CANNONDALE', 3),
#  ('INGRAM MICRO', 3),
#  ('VCM', 3),
#  ('C. Bomann GmbH', 3),
#  ('TOSHIBA EUROPE', 2),
#  ('COOPER EIGENMARKE', 2),
#  ('GGV HANDELSGESMBH&COKG', 2),
#  ('INTERN', 2),
#  ('VR', 2),
#  ('MPG&E CONTACTLINSEN GMBH', 2),
#  ('SWISSLENS', 2),
#  ('BOSCH -W-', 2),
#  ('SHARP', 2),
#  ('CONTA OPTIK', 2),
#  ('WÖHLK-CONTACTLINSEN GMBH', 2),
#  ('CORSAIR MEMORY', 2),
#  ('CINELLI', 2),
#  ('MEDIARANGE', 2),
#  ('TDK MEDIA', 2),
#  ('CHIPS AND MORE', 2),
#  ('COOPER EYE^2', 2),
#  ('LOGSERVE LS1&LS3', 2),
#  ('PNY ELECTR', 2),
#  ('GROUP SFIT', 2),
#  ('CONTACTLINSEN', 2),
#  ('BV CYCLES', 2),
#  ('SEAGATE', 2),
#  ('OCULSOFT SAUFLON', 2),
#  ('MIELE & CIE. KG91402', 2),
#  ('HAMLET', 2),
#  ('KAWASAKI', 2),
#  ('CISCO SYSTEMS', 2),
#  ('VER', 2),
#  ('CONSUMABILI IMATION', 2),
#  ('MY DOODLES', 2),
#  ('EYECATCHER', 2),
#  ('Kingston', 2),
#  ('HAMA GMBH & COKG', 2),
#  ('GORENJE HAUSGERäTE', 2),
#  ('4 CARE AG', 2),
#  ('SD', 2),
#  ('AEG - HAUSGERAETE', 2),
#  ('WHIRLPOOL', 2),
#  ('IGA-OPTIK', 2),
#  ('TREKSTOR', 2),
#  ('ONUX', 2),
#  ('OCULSOFT CIBA', 2),
#  ('HOTPOINT-ARISTON', 2),
#  ('SOENNECKEN EG LS3', 2),
#  ('HP INC.', 2),
#  ('MBM CICLE', 2),
#  ('DEXXON DATA MEDIA', 2),
#  ('SIEMENS-ELEKTROGERAETE GMBH', 2),
#  ('FANBIKE KG', 2),
#  ('LG-ELECTRONIC', 2),
#  ('<NONE>', 2),
#  ('MPG & E', 2),
#  ('ELECTROLUX HAUSGERäTE GMBH AEG', 2),
#  ('BAUSCH+LOMB', 2),
#  ('NEFF HNP', 2),
#  ('ALCON/CIBA VISION', 2),
#  ('SOENNECKEN LOGSERVE GMBH', 2),
#  ('OCULSOFT COOPER VISION', 2),
#  ('SAUFLON PHARMACEUTIC', 2),
#  ('CHARGE', 2),
#  ('NEFF', 2),
#  ('PRIVILEG', 2),
#  ('HANSEATIC', 2),
#  ('REX SPORT', 2),
#  ('DIVERSE MARKEN', 2),
#  ('VISTAKON', 2),
#  ('EYELIKE GMBH', 2),
#  ('BÃ¼NTING SYSTEMKUNDEN HANDELS-GMBH', 2),
#  ('SAMSUNG -W-', 2),
#  ('Puky GmbH & Co. KG', 2),
#  ('BÃ¼NTING GROÃŸHANDEL & SERVICE GMBH', 2),
#  ('MIELE+CIE. KG', 2),
#  ('MONTANA', 2),
#  ('MIELE & CIE.KG', 2),
#  ('BOSCH VERKAUFSB.', 2),
#  ('SAUFLON PHARMACEUTICALS GM', 2),
#  ('ACUVUE® KONTAKTLINSEN', 2),
#  ('KTM FAHRRAD GMBH', 2),
#  ('ALCON  PHARMA  VISIONCAR', 2),
#  ('BAUSCH UND LOMB', 2),
#  ('NILOX MEMORIE', 2),
#  ('JOHNSON&JOHNSON', 2),
#  ('CANDY HOOVER GMBH', 2),
#  ('TERN', 2),
#  ('MEDIACOM IT-DISTRIBUTION', 2),
#  ('HAWK BIKE SALES GMBH', 2),
#  ('MAXELL CONSUMABILI', 2),
#  ('SAMSUNG WW', 2),
#  ('ALSO DEUTSCHLAND GMBH', 2),
#  ('NO NAME', 2),
#  ('ELECTROLUX HAUSGERAETE GMBH AEG', 2),
#  ('SAMSUNG  ELECTRONICS GMBH', 2),
#  ('SEG HAUSGERäTE GMBH', 2),
#  ('SEG HAUSGERÃ¤TE GMBH', 2),
#  ('Conta Optik', 2),
#  ('LG ELECTRONICS', 2),
#  ('KOENIC', 2),
#  ('B + L', 2),
#  ('DAILIES', 2),
#  ('HOTPOINT', 2),
#  ('GALIFA', 2),
#  ('BAUKNECHT HAUSGERäTE GMBH', 2),
#  ('SAMSUNG ELECTRONICS GMBH', 2),
#  ('COOLMOBILITY  (S´COOL)', 2),
#  ('MPG+E', 2),
#  ('MIMOBOT', 2),
#  ('SOENNECKEN LS1', 2),
#  ('JOHNSON&JOHNSON VISION CAR', 2),
#  ('POLAR', 1),
#  ('ALKA', 1),
#  ('sandisk', 1),
#  ('GEOBRA-BRANDSTAETT.STIFT.', 1),
#  ('ARCTIC', 1),
#  ('DIV. HERSTELLER', 1),
#  ('SOENNECKEN / LS: 1', 1),
#  ('MIFA MITTELDEUTSCHE', 1),
#  ('HAMA GMBH & CO. KG', 1),
#  ('HP ENTERPRISE', 1),
#  ('BRANION LOGSERVE SOE LS1', 1),
#  ('INTEGRAL MEMORY', 1),
#  ('ALCON PHARMA', 1),
#  ('TRANSIMEX SERVICE GMBH', 1),
#  ('BRANION GMBH', 1),
#  ('Geobra Brandstätter', 1),
#  ('LEXAR MEDIA', 1),
#  ('MADD GEAR', 1),
#  ('BOSE', 1),
#  ('XLAYER', 1),
#  ('RIDLEY BIKES', 1),
#  ('ALCON(CIB)', 1),
#  ('3503460', 1),
#  ('KGT', 1),
#  ('MACH XTREME TECHNOLOGY', 1),
#  ('NS BIKES', 1),
#  ('FREQUENCY XCEL TORIC', 1),
#  ('INFD32GBBLK', 1),
#  ('MIELE&CIE.KG VERKAUFSGESELLSCH', 1),
#  ('BABBOE', 1),
#  ('ULTRASPORT', 1),
#  ('Constructa-Neff Vertriebs GmbH', 1),
#  ('SYSTEAM GMBH', 1),
#  ('HAMA GMBH & CO', 1),
#  ('SIEMENS -W-', 1),
#  ('Alno AG', 1),
#  ('WÖHLK-CONTACTLINSEN', 1),
#  ('DISNEY', 1),
#  ('ELECTRONICPARTNER', 1),
#  ('BÜROBOSS.DE/LOGISTIK', 1),
#  ('BUERORING EG', 1),
#  ('BAUSCH&LOMB GMBH', 1),
#  ('#SANDISK', 1),
#  ('12124', 1),
#  ('Verbatim', 1),
#  ('0', 1),
#  ('NETAPP', 1),
#  ('CONSUMABILI MAXELL', 1),
#  ('INTEGRAL™', 1),
#  ('3500470', 1),
#  ('HUDORA', 1),
#  ('HPE', 1),
#  ('SOENNECKEN  *MGW', 1),
#  ('ELECTROLUX HAUSGERäTE GMBH ZANKER', 1),
#  ('MONATS KL', 1),
#  ('COOLMOBILITY GMBH', 1),
#  ('TOP EDITION', 1),
#  ('KINGSTON TECHNOLOGY GMBH', 1),
#  ('DGH FOTOHANDEL', 1),
#  ('SILVER SANZ', 1),
#  ('JOHNSON & JOHNSON VISION C', 1),
#  ('APPENZELLER KONTAKTLINSEN', 1),
#  ('KNOLLELEKTROGROSSHANDEL', 1),
#  ('SEG Hausgeräte GmbH', 1),
#  ('3531470', 1),
#  ('CADENCE', 1),
#  ('BOSCH HAUSGERAETE GMBH96033', 1),
#  ('WÖHLK- CONTACTLINSEN', 1),
#  ('DANCKER', 1),
#  ('HYDROGEL VISION CORPORATION', 1),
#  ('CONSTRUCTA - NEFF', 1),
#  ('CANDY-HOOVER GMBH', 1),
#  ('KIN', 1),
#  ('MIELE-GROSSGERAETE', 1),
#  ('WILK ELEKTRONIK', 1),
#  ('5 STAR', 1),
#  ('TOONSTAR', 1),
#  ('TECHNOLENS', 1),
#  ('I-CARE VISION BV', 1),
#  ('MISCO', 1),
#  ('IN', 1),
#  ('I.ONIK', 1),
#  ('SIEMENES', 1),
#  ('JOHNSON & JOHNSON MEDI', 1),
#  ('VERSCH.', 1),
#  ('ALCON PHARMA NOVARTIS GMBH', 1),
#  ('LACIE\xa0COMPONENTES', 1),
#  ('GGV HANDELSGESELLSCHAFT MBH', 1),
#  ('REDDY-AEG PR', 1),
#  ('MIELE EB FH UVP', 1),
#  ('ACUVUENEU', 1),
#  ('SWISS LENS KATALOG', 1),
#  ('3521472', 1),
#  ('BIOMEDICS', 1),
#  ('Intenso', 1),
#  ('VISTAKON/J+J', 1),
#  ('PRIMA-OPTICS', 1),
#  ('ADAM ELEMENTS', 1),
#  ('EURONICS DEUTSCHLAND EG', 1),
#  ('BBF', 1),
#  ('MOOSTER', 1),
#  ('RINGFOTO', 1),
#  ('CONTA OPITK', 1),
#  ('DTO.', 1),
#  ('2191278', 1),
#  ('MIELE CLASS UVP', 1),
#  ('49812', 1),
#  ('SanDisk', 1),
#  ('XD', 1),
#  ('COOPER DEZZ30065', 1),
#  ('COOPER VISION/SAUFLON', 1),
#  ('REX BIKE', 1),
#  ('AGI', 1),
#  ('MY BONNY', 1),
#  ('CHIPS & MORE GMBH/SUEDFACTORIN', 1),
#  ('#KINGSTON', 1),
#  ('EP:', 1),
#  ('MPG&E KATALOG', 1),
#  ('DACAPO', 1),
#  ('MEDIACOM', 1),
#  ('TOIMS', 1),
#  ('SANDISK CORPORATION', 1),
#  ('BACHTENKIRCH INTERBIKE', 1),
#  ('LGKT5', 1),
#  ('HP', 1),
#  ('BACHTENKIRCH-INTERBIKE', 1),
#  ('CIBAVISION', 1),
#  ('VERBATIM GMBH', 1),
#  ('PC', 1),
#  ('SILICON', 1),
#  ('TRC', 1),
#  ('7916000', 1),
#  ('OPTICLAND EIGENMARKE', 1),
#  ('SMEG', 1),
#  ('OK.', 1),
#  ('EGS OPTIK', 1),
#  ('BOSCH ROB.HAUSGERäTE GMBH', 1),
#  ('CONSTRUCTA-NEFF', 1),
#  ('ELECTRONICPARTNER GMBH', 1),
#  ('COOPER KATALOG', 1),
#  ('DIVERSE MARKEN MEDIMAX', 1),
#  ('OPTICLAND', 1),
#  ('TECHNO', 1),
#  ('CISCO', 1),
#  ('DIV.', 1),
#  ('JOHNSON+JOHNSON', 1),
#  ('EDIT', 1),
#  ('DIVERSE FABRIKATE', 1),
#  ('AUTODRIVE', 1),
#  ('EIGEN', 1),
#  ('J.&J.', 1),
#  ('CANTON', 1),
#  ('SIEMENS-Electrogeräte', 1),
#  ('IGA IGK', 1),
#  ('CONCEPT', 1),
#  ('CIBA-VISION', 1),
#  ('PEACOCK', 1),
#  ('AD AUTODRIVE', 1),
#  ('CHIPS & MORE GMBH', 1),
#  ('DISNEY INTERACTIVE', 1),
#  ('LENOVO', 1),
#  ('ULTRA', 1),
#  ('POPAL', 1),
#  ('TECHNAXX', 1),
#  ('MAXELL', 1),
#  ('COOPER/SAUFLON', 1),
#  ('CIBA  VISION', 1),
#  ('UNKNOWN', 1),
#  ('JOHNSON & JOHNSON MEDICAL', 1),
#  ('SON', 1),
#  ('VENTANA BEKLEIDUNGSFABRIKATION GMBH', 1),
#  ('PNY TECHNOLOGIES GMBH', 1),
#  ('INTERFUNK', 1),
#  ('HAIER DEUTSCHLAND GMBH', 1),
#  ('BAUSCH  & LOMB GMBH', 1),
#  ('STREBEL-HILTWEIN', 1),
#  ('VERBATIM CONSUMABILI', 1),
#  ('COOPER VISION WES', 1),
#  ('TECHNO LENS', 1),
#  ('PQI', 1),
#  ('UNOTEC', 1),
#  ('MANAGERSEMINARE VERLAGS GMBH', 1),
#  ('ACER', 1),
#  ('TELEKOM DEUTSCHLAND', 1),
#  ('HECHT CL', 1),
#  ('GALFILA CONTACTLINSEN GMBH', 1),
#  ('TAKE MS', 1),
#  ('CIBA KATALOG', 1),
#  ('GRFE3|#GREGSTER', 1),
#  ('COOPER  VISION', 1),
#  ('VIDEOSEVEN', 1),
#  ('PRETEC', 1),
#  ('STAPLES', 1),
#  ('INTEGRAL MEMORY PLC', 1),
#  ('GORENJE HAUSGERAETE', 1),
#  ('GRUNDIG.', 1),
#  ('TECHNO LENS DEUTSCHLA', 1),
#  ('ROOSTER', 1),
#  ('BIANCHI', 1),
#  ('ELECTROLUX HAUSGERAETE GMBH', 1),
#  ('SAMSUNG UFD', 1),
#  ('EYE2', 1),
#  ('Bauknecht', 1),
#  ('TOSHIBA EUROPE GMBH', 1),
#  ('ETHICON-JOHNSON & JOHNSO', 1),
#  ('JOHNSON&JOHNSON VISION CA', 1),
#  ('BOSCH HAUSGERAETE GMBH', 1),
#  ('JOHNSON & JOHNSON VI', 1),
#  ('GORENJE VERTRIEBS GMBH', 1),
#  ('ELECTROLUX HAUSGERäTE VERTIEBS', 1),
#  ('COOPER VISION KATALOG', 1),
#  ('CHIPS & MORE', 1),
#  ('AEG HAUSGERAETE GMBH INNENDIEN', 1),
#  ('JOHNSON & JOHNSO', 1),
#  ('PRESTIGIO', 1),
#  ('PC?: WORTMANN AG', 1),
#  ('COMFEE', 1),
#  ('ADATA TECHNOLOGY (USA) CO., LTD', 1),
#  ('BAUSCH-AND-LOMB', 1),
#  ('V7-WORLD', 1),
#  ('SWISSLENS SCHWEIZ', 1),
#  ('DIVERSE HERSTELLER', 1),
#  ('IUK', 1),
#  ('CONSUM.TDK', 1),
#  ('MARKENNOVY', 1),
#  ('CM08CR000', 1),
#  ('ROBERT BOSCH HAUSGERÃ¤TE GMBH', 1),
#  ('ALCON VISION CARE', 1),
#  ('KINGSTON TECHNOLOGY EUROPE LIM', 1),
#  ('PKM', 1),
#  ('INGRAM MICRO SERVICES', 1),
#  ('ROBERT BOSCH HAUSGERäTE GMBH', 1),
#  ('DAEWOO', 1),
#  ('CAMRY', 1),
#  ('MPGE', 1),
#  ('ARP', 1),
#  ('FISCHER DIE FAHRRADMARKE', 1),
#  ('4,242E+12', 1),
#  ('ZUENDAPP', 1),
#  ('DELL', 1),
#  ('J & J', 1),
#  ('KHEBIKES', 1),
#  ('HEINRICH WÖHLK CONTACTLINS', 1),
#  ('COOPER-VISION', 1),
#  ('HISENS', 1),
#  ('SMEG HAUSGERAETE GMBH', 1),
#  ('SIEWERT', 1),
#  ('ELECTROLUX HAUSGERAETE GMBH80124', 1),
#  ('STEPPENWOLF', 1),
#  ('CTC CLATRONIC INTERNAT', 1),
#  ('BOSCH KG', 1),
#  ('MPG&E HANDEL UND SERVICE G', 1),
#  ('MIRU', 1),
#  ('AKTUELL', 1),
#  ('LG ELECTRONICS DEUTSCHLAND', 1),
#  ('LGELECTRONICS', 1),
#  ('Soennecken eG', 1),
#  ('AMA', 1),
#  ('APPENZELLER', 1),
#  ('HEAD', 1),
#  ('AEG HAUSGERäTE', 1),
#  ('INSMAT', 1),
#  ('TRANSMEMORY', 1),
#  ('90890', 1),
#  ('STRIDER', 1),
#  ('NO-NAME', 1),
#  ('AEG LIN MHK/VME', 1)]

# %%
# build the manufacturer-category matrix, to see whether there 
# exists a strong link between certain manufacturers and categories
from nltk import ConditionalFreqDist
mnf_ctg_matrix = ConditionalFreqDist(
    (manufacture_list[idx], category_list[idx]) for idx in list(range(8000))
)
print('manufacturer\tnum. of corresponding categories')
for mnf in unique_mnf:
    print(mnf, '\t', len(mnf_ctg_matrix[mnf].most_common()))
# Out:
# manufacturer	num. of corresponding categories
# nan 	 4
# ACUVUE 	 1
# HP 	 1
# COLOURVUE 	 1
# BACH 	 1
# DEXXON DATA MEDIA 	 1
# MPG & E 	 1
# HAMA GMBH & CO. KG 	 1
# MPG&E-CONTACTLINSEN 	 1
# MADD GEAR 	 1
# SWISSLENS 	 1
# BOSCH -W- 	 1
# PENDING SYSTEM GMBH&CO.KG,,956 	 1
# BÃ¼NTING SYSTEMKUNDEN HANDELS-GMBH 	 1
# STAPLES 	 1
# GORENJE HAUSGERAETE 	 1
# IGA-OPTIK 	 1
# COOPER VISION WES 	 1
# BOSCH 	 1
# BOSCH KG 	 1
# PERFORMANCE 	 1
# CONSTRUCTA ENERGY 	 1
# DIVERSE 	 1
# PLATINUM 	 1
# XD 	 1
# BACHTENKIRCH INTERBIKE 	 1
# KAWASAKI 	 1
# BAUSCH  & LOMB GMBH 	 1
# TAKEMS SONDERPOSTEN 	 1
# MERALENS 	 1
# HYDROGEL V 	 1
# BAUSCH + LOMB 	 1
# ELECTROLUX HAUSGERäTE GMBH AEG 	 1
# I.ONIK 	 1
# HECHT CL 	 1
# OTTO GMBH & CO. KG 	 1
# EXQUISIT 	 1
# CNMEMORY 	 1
# BAUSCH&LOMB 	 1
# RIXE 	 1
# GGV HANDELSGESMBH&COKG 	 1
# SI-ZWEIRAD-VERTRIEBS-GMBH 	 1
# REX SPORT 	 1
# PATRIOT 	 1
# MIELE 	 1
# ALCON 	 1
# DACAPO 	 1
# VERBATIM CONSUMABILI 	 1
# CONTA OPTIK 	 1
# EP: 	 1
# CIBA VISION 	 1
# UNKNOWN 	 1

# %% [markdown]
# I find that, mostly, each manufacture corresponds to only one category. Hence I would first develop a *Naive Bayes* type model as a baseline: maintain the probabilities p(category|manufacturer); if a manufacturer corresponds to multiple categories, I would predict the most likely one.

# %%
# split data into train, dev and test set by ratio 6:2:2
import random
train_idx, dev_idx, test_idx = [], [], []
for i in range(len(category_list)):
    rnd = random.random()
    if rnd <= 0.6: train_idx.append(i)
    elif rnd <= 0.8: dev_idx.append(i)
    else: test_idx.append(i)

print('train size', len(train_idx))
print('dev size', len(dev_idx))
print('test size', len(test_idx))
# Out:
# train size 4743
# dev size 1599
# test size 1658

# %%
# a baseline model: predict based on p(category|manufacturer)
baseline_pred = []
mnf_ctg_matrix = ConditionalFreqDist(
    (manufacture_list[idx], category_list[idx]) for idx in train_idx+dev_idx
)

for mnf in [manufacture_list[i] for i in test_idx]:
    # if the manufacturer has seen in the training set, label it with its most probable category
    if mnf in mnf_ctg_matrix: baseline_pred.append(mnf_ctg_matrix[mnf].max())
    # otherwise, return either of the category uniformly randomly
    else: baseline_pred.append(random.choice(unique_ctg))

test_true_catgy = [category_list[i] for i in test_idx]
acc = len([1 for (pred,true) in zip(baseline_pred,test_true_catgy) if pred==true])*1./len(baseline_pred)
print('manufacturer-only baseline accuracy', acc)
# Out:
# manufacturer-only baseline accuracy 0.8516284680337757

# %% [markdown]
# Given the baseline performance, I would use the text information from main_text and add_text to make predictions. More specifically, I would use the tf-idf vectors of the texts as input to train a Logistic Regression based classifier.

# %%
# use tf-idf vectors to represent text, use logistic regression as classifier
# !pip install -U sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# prepare data
main_text_list = data['main_text'].tolist()
add_text_list = data['add_text'].tolist()

wanted_text = 'merged' # or 'only add' or 'only main'
if 'only main' == wanted_text:
    text_list = main_text_list
elif 'only add' == wanted_text:
    text_list = add_text_list
else:
    text_list = [repr(main_text_list[i])+' '+repr(add_text_list[i]) for i in range(len(main_text_list))]

train_text = [repr(text_list[i]) for i in train_idx]
train_cat = [repr(category_list[i]) for i in train_idx]
dev_text = [repr(text_list[i]) for i in dev_idx]
dev_cat = [repr(category_list[i]) for i in dev_idx]
test_text = [repr(text_list[i]) for i in test_idx]
test_cat = [repr(category_list[i]) for i in test_idx]

# this function facilitates trying out different hyperparameters of the classifier
def train_model(nrange, mf_num):
    tfidf_vectorizer = TfidfVectorizer(ngram_range=nrange,max_features=mf_num,sublinear_tf=True)
    train_vecs = tfidf_vectorizer.fit_transform(train_text)
    dev_vecs = TfidfVectorizer(vocabulary=tfidf_vectorizer.vocabulary_,ngram_range=nrange,max_features=mf_num,sublinear_tf=True).fit_transform(dev_text)
    clf = LogisticRegression().fit(train_vecs, train_cat)
    acc = clf.score(dev_vecs, dev_cat)
    return clf, acc, tfidf_vectorizer.vocabulary_

# %%
# find the best hyper-parameters combinations on dev test

ngram_list = [(1,1),(1,2),(1,3),(2,3)]
mfnum_list = [100,500,1000,3000,5000,8000,10000,15000,20000]
best_acc = -1
best_clf = None
best_setup = None
best_vocab = None

for ngram in ngram_list:
    for mfnum in mfnum_list:
        clf, acc, vocab = train_model(ngram,mfnum)
        print(ngram, mfnum, acc)
        if acc > best_acc:
            best_acc = acc
            best_clf = clf
            best_setup = (ngram, mfnum)
            best_vocab = vocab
            
print('\n===========')
print('best setup', best_setup)
print('best acc', best_acc)
# Out:
# (1, 1) 100 0.9724828017510945
# (1, 1) 500 0.991869918699187
# (1, 1) 1000 0.9956222639149468
# (1, 1) 3000 0.9956222639149468
# (1, 1) 5000 0.9956222639149468
# (1, 1) 8000 0.9962476547842402
# (1, 1) 10000 0.9962476547842402
# (1, 1) 15000 0.9962476547842402
# (1, 1) 20000 0.9962476547842402
# (1, 2) 100 0.9668542839274546
# (1, 2) 500 0.9881175734834271
# (1, 2) 1000 0.9931207004377736
# (1, 2) 3000 0.9956222639149468
# (1, 2) 5000 0.9956222639149468
# (1, 2) 8000 0.9956222639149468
# (1, 2) 10000 0.9956222639149468
# (1, 2) 15000 0.9956222639149468
# (1, 2) 20000 0.9956222639149468
# (1, 3) 100 0.9649781113195748
# (1, 3) 500 0.9862414008755472
# (1, 3) 1000 0.9924953095684803
# (1, 3) 3000 0.9956222639149468
# (1, 3) 5000 0.9956222639149468
# (1, 3) 8000 0.9956222639149468
# (1, 3) 10000 0.9956222639149468
# (1, 3) 15000 0.9956222639149468
# (1, 3) 20000 0.9956222639149468
# (2, 3) 100 0.6779237023139462
# (2, 3) 500 0.858036272670419
# (2, 3) 1000 0.8974358974358975
# (2, 3) 3000 0.9355847404627893
# (2, 3) 5000 0.9418386491557224
# (2, 3) 8000 0.9468417761100688
# (2, 3) 10000 0.9468417761100688
# (2, 3) 15000 0.9462163852407754
# (2, 3) 20000 0.9468417761100688
#
# ===========
# best setup ((1, 1), 8000)
# best acc 0.9962476547842402

# %%
# check the classifier's performance on test set
test_vecs = TfidfVectorizer(vocabulary=best_vocab,ngram_range=best_setup[0],max_features=best_setup[1],sublinear_tf=True).fit_transform(test_text)
test_acc = best_clf.score(test_vecs, test_cat)
print(test_acc)
# Out:
# 0.9981905910735827

# %% [markdown]
# ## Analysis
# I have repeated the experiments for 10 times, each time with a different train/dev/test split (in the same ratios). I made the following major observations.
# * Using *main_text* and *add_text* together yields the best performance (accuracy consistantly above 0.99 on both dev and test set), followed by using *main_text* only (acc >0.98) and *add_text* only (acc >0.95), all better than the manufacturer-based baseline by a large margin.
# * At each run, I find the accuracy at test and dev set are very similar, suggesting that the model is not overfitted.
# * All the weights learnt by the logistic regression model look right (e.g. no exgtremely large or small values), suggesting that the learned classifier is sensible. The most and least informative features for each class are presented below.

# %%
# check the most and least informative features, in terms of their corresponding weights
# !pip install -U numpy
import numpy as np
weights_matrix = best_clf.coef_
for i,catgy in enumerate(best_clf.classes_):
    print('\n======={}========'.format(catgy))
    sorted_weights = sorted(weights_matrix[i])
    weights = list(weights_matrix[i])
    dic = {word:weight for (word,weight) in zip(best_vocab,weights)}
    sorted_dic = {k: v for k, v in sorted(dic.items(), key=lambda item: np.abs(item[1]))}
    print('---most informative features---')
    for ww in list(sorted_dic.keys())[-20:]:
        print(ww,'\t', sorted_dic[ww])
    print('---least informative features---')
    for ww in list(sorted_dic.keys())[:10]:
        print(ww, '\t', sorted_dic[ww])
# Out:
# ======='BICYCLES'========
# ---most informative features---
# 21gang 	 -1.6110399724510758
# interner 	 1.6532246330497573
# action 	 -1.6709486602478556
# 11100 	 1.7009710201668746
# silicone 	 1.7891281468306897
# wasch 	 -1.8719913533184505
# flexx 	 1.872802482067686
# 342 	 -1.9392541548188869
# tdosxl 	 -1.9409259210996976
# merida 	 1.9692421916966345
# leistungsfaehiger 	 1.9692421916966345
# summe7613317058850 	 1.9802554466582585
# 6513612106 	 2.011903661688615
# vim 	 2.1143789242201496
# 49l 	 2.2400677199092387
# 109 	 2.4232009769753757
# dokumenten 	 -2.777697221817248
# ecoedition 	 2.9299554906285192
# presbyopia 	 5.037362979109216
# brake 	 5.831228885405922
# ---least informative features---
# prob 	 -0.00025130474849383206
# pd2gh2grtsbbl 	 -0.0004889499904894042
# 763513 	 -0.0005884401774260179
# keine 	 -0.0006737667653951939
# extra90 	 -0.0006996215216652044
# igk 	 -0.0007398801682650466
# wp12t227 	 -0.0008122199285723724
# masse 	 -0.0008299100816094179
# preiseinheit 	 -0.0008725725351952962
# micu3 	 -0.0008811204470398108
#
# ======='CONTACT LENSES'========
# ---most informative features---
# 1027 	 1.4696742891011068
# brake 	 -1.4705290647579818
# 451872 	 1.5102547012221461
# contactindi 	 1.5249740577084252
# rdk 	 1.5283804428907588
# 623031013 	 1.5311263495528649
# lavender 	 1.5886156157056057
# beetle 	 1.6539243958680663
# ne 	 1.681722971497388
# 380s 	 1.8560953828137046
# dokumenten 	 -1.86073802417935
# coco 	 1.9775849412592073
# we 	 2.046086558803251
# 751530__75 	 2.1839188166322807
# 37 	 2.495684275798171
# tdosxl 	 2.551531103165471
# vista 	 2.6292376486159577
# 21gang 	 4.750417922870341
# action 	 4.940201866854063
# wasch 	 5.500540236155097
# ---least informative features---
# prob 	 -0.00025259203081363745
# biomedics 	 0.00034299910992522656
# pd2gh2grtsbbl 	 -0.0004437866262410419
# waschtrockner 	 0.0005232397964749903
# externes 	 -0.0005237442465714002
# beladungsmenge 	 -0.0005237442465714002
# friars 	 -0.0005296051891621061
# 1_6_7 	 -0.0005376080904125215
# 763513 	 -0.0005592656948674075
# athabasca 	 -0.0005665747795459741
#
# ======='USB MEMORY'========
# ---most informative features---
# presbyopia 	 -1.4492800909535186
# 521405 	 1.4507072591982628
# wab282mk 	 1.4522250836210653
# ride 	 1.4805945638213243
# weich 	 1.4885448909241799
# extraklasse 	 1.6016783299647814
# encryption 	 1.6420909074979855
# einrohr 	 1.6836421985368235
# brake 	 -1.7147068831187648
# choice 	 1.7688275876382467
# l76471pfl 	 1.9993067067666317
# transme 	 2.1311067121756575
# motto 	 2.2987746392968504
# inverter 	 2.3780633796888275
# watpla782 	 3.0481896275312366
# wmv960wps 	 3.126653613374017
# silberfarben 	 3.209938673130207
# massenspeicher 	 3.5096207643200215
# deckende 	 4.339803244548364
# dokumenten 	 7.870722209844084
# ---least informative features---
# girly 	 0.0004637383047971746
# health 	 0.0005236721444509354
# keine 	 -0.000617868972377799
# externes 	 -0.0006418116100370726
# beladungsmenge 	 -0.0006418116100370726
# fd004410 	 -0.0006833631678725651
# elektronik 	 -0.0007139680494031815
# prob 	 0.0007925918813783598
# pop 	 -0.0008851287345662481
# 530 	 -0.0010487862382245743
#
# ======='WASHINGMACHINES'========
# ---most informative features---
# 417953 	 1.8080193571320635
# xtremkey 	 1.8507865892587387
# 21gang 	 -1.8880430550724816
# remo 	 1.9008382045750805
# haag 	 1.9177364376958241
# hw80 	 1.9410626826950643
# steppenwolf 	 1.9468188197558807
# action 	 -1.9736215380957314
# 99 	 2.020810112277159
# raiser 	 2.2298894249359886
# wasch 	 -2.2938744714673938
# 130mb 	 2.3041438692450393
# hdm0nh 	 2.3245307991088797
# presbyopia 	 -2.3778646664190606
# haushaltsgrossgeraete_waschmaschinen_constructa 	 2.4824917914922366
# brake 	 -2.6459929375291624
# 19550 	 2.875657955691893
# dokumenten 	 -3.2322869638474936
# ft 	 3.5203747322709646
# 342 	 4.518109043373637
# ---least informative features---
# prob 	 -0.0002886951020708537
# 1_6_7 	 -0.0005338617585921679
# pd2gh2grtsbbl 	 -0.00054789122084551
# externes 	 -0.0005639438023945091
# beladungsmenge 	 -0.0005639438023945091
# athabasca 	 -0.0006417960278508772
# himmelblau 	 -0.0006454731879447969
# 763513 	 -0.0006952092906319146
# 04841 	 -0.0007224742587638774
# igk 	 -0.0008130912740447358

# %% [markdown]
# ## API For The Trained Classifier
#
# I have no experiences in developing REST APIs. Hence, due to the time limit, I did not implement it. To implement a REST API, in principle, I would first save *best_clf*, *best_vocab* and *best_setup* using *pickle*, so as to re-use these variables to vectorise next text and perform the classification. A very simple API is impelemented below.

# %%
# API for the trained classifier
def make_predictions(input_text):
    test_vecs = TfidfVectorizer(vocabulary=best_vocab,ngram_range=best_setup[0],max_features=best_setup[1],sublinear_tf=True).fit_transform(input_text)
    predictions = best_clf.predict(test_vecs)
    return predictions

test_text = ['guten tag','USB 3.0','hallo walt!']
print(make_predictions(test_text))
# Out:
# ["'WASHINGMACHINES'" "'USB MEMORY'" "'WASHINGMACHINES'"]
